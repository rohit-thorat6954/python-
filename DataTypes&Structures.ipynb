# %%
Q1) what are data structures,and why are they important?
>> Data structures are ways to store and organize data efficiently for specific uses,and they are important because they determine
    how quickly data can be accessed,managed,and processed.

# %%
Q2) Explain the difference between mutable and immutable data types with example.
>> Mutable data types can be changed after they created,while immutable data types cannot

# %%
Q3) what are the main difference between lists and tuples in python?
>> Lists are mutable, while tuples are immutable.

# %%
Q4) Describe how dictionaries store data.
>> Dictionaries store data in key-value pairs.

# %%
Q5) why might you use a set instead of a list in python?
>> Sets automatically handle unique elements and provide faster membership testing and removal of duplicates.

# %%
Q6) what is a string in python, and how is it different from a list?
>> A string is an immutable sequence of characters, while a list is a mutable sequence that can hold items of various data types.

# %%
Q7) How do tuples ensure data intergity in python?
>> Immutability

# %%
Q8) what is a hash table,and how does it relate to dictionaries in python?
>> A hash table is a data structure that implements an associative array abstract data type,a structure that can map keys to values.

# %%
Q9) Can lists contain different data types in python?
>> yes lists in python can contain different data types.

# %%
Q10) Explain why strings are immutable in python.
>> Strings are immutable in python to ensure data integrity,make them memory-efficient,and allow them to be safely shared and used in certain 
  data structures.

# %%
Q11) what advantages do dictionaries offer over lists for certain tasks?
>> 1)Dictionaries offer key-based access and faster lookups for specific values
 while lists are ordered sequences best suited for indexed access.

# %%
Q12) Describe a scenario where using a tuple would be perferable over a list.
>> Storing a fixed collection of related iteams,such as coordinates or database records,that should not be changed after creation.

# %%
Q13) How do sets handle duplicate values in python?
>> Sets automatically discard duplicate values, ensuring each element is unique.

# %%
Q14) How does the "in" keyword work differently for lists and dictionaries?
>> the in keyword checks for membership differently based on the data structure's underlying implementation and time complexity.

# %%
Q15) can you modify the elements of a tuple? Explain why or not.
>> No 
   Tuples are immutable data structures in many programming languages

# %%
Q16) what is a nested dictionary,and give an example of its use case?
>> A nested dictionary is a dictionary where one or more of its values are themselves dictionaries.

# %%
Q17) Describe the time complexity of accessing elements in dictionary.
>> 0(1)
   Dictionaries use a hash table data structure

# %%
Q18) In what situations are lists preferred over dictionaries?
>> When the order of elements matters,or when data needs to be accessed by numerical index.

# %%
Q19) why are dictionaries considered unordered,and how does that affect data retrieval?
>> because they do not guarantee that the order of items will be preserved

# %% [markdown]
# #PRACTICAL

# %%
Q1) Write a code to create a string with your name and print it.

# %%
name = "Rohit"
print(name)
# Out:
# Rohit

# %%
Q2) write a code to find the length of the string "Hello World".

# %%
my_string = "Hello world"
length = len(my_string)
print(length)
# Out:
# 11

# %%
Q3) Write a code to slice the first 3 characters from the string "Python Programming".

# %%
s = "python programming"
s[0 : 3]
# Out:
# 'pyt'

# %%
Q4) Write a code to convert the string "Hello" to uppercase.

# %%
text = "Hello"
uppercase_text = text.upper()
print(uppercase_text)
# Out:
# HELLO

# %%
Q5) Write a code to replace the word "apple" with "orange" in the string "I like apple".

# %%
original_string = "i like apple"
new_string = original_string.replace("apple", "orange")
print(new_string)
# Out:
# i like orange

# %%
Q6) Write a code to create a list with numbers 1 to 5 and print it.

# %%
numbers = list(range(1, 6))
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
Q7) write a code to append the number 10 to the list [1,2,3,4].

# %%
my_list = [1, 2, 3, 4]
my_list.append(10)
print(my_list)
# Out:
# [1, 2, 3, 4, 10]

# %%
Q8) Write a code to remove the number 3 from the list [1,2,3,4,5].

# %%
my_list = [1,2,3,4,5]
my_list.remove(3)
print(my_list)
# Out:
# [1, 2, 4, 5]

# %%
Q9) write a code to access the second element in the list ['a','b','c','d'].

# %%
my_list = ['a','b','c','d']
second_element = my_list[1]
print(second_element)
# Out:
# b

# %%
Q10) Write a code to reverse the lists [10,20,30,40,50].

# %%
my_list = [10,20,30,40,50]
my_list.reverse()
print(my_list)
# Out:
# [50, 40, 30, 20, 10]

# %%
Q11) write a code to create a tuple with elements 100,200,300 and print it.

# %%
t = (100,200,300)
print(t)
# Out:
# (100, 200, 300)

# %%
Q12) write a code to access the second-to-last element of the tuple ('red','green','blue','yellow').

# %%
my_tuple = ('red','green','blue','yellow')
second_to_last = my_tuple[-2]
print(second_to_last)
# Out:
# blue

# %%
Q13) write a code to find the minimum number in the tuple (10, 20, 5, 15)

# %%
numbers = (10, 20, 5, 15)
minimum_number = min(numbers)
print(minimum_number)
# Out:
# 5

# %%
Q14) write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')

# %%
my_tuple = ('dog', 'cat', 'rabbit')
index_of_cat = my_tuple.index('cat')
print(index_of_cat)
# Out:
# 1

# %%
Q15) write a code to create a set with the elements 'a','b','c' and print it.

# %%
my_set = {'a','b','c'}
print(my_set)
# Out:
# {'b', 'c', 'a'}

# %%
Q16) write a code to create a tuple containing three different fruits and check if"kiwi" is in it

# %%
fruits = ('apple', 'banana','orange')
if "kiwi" in fruits:
    print("kiwi is in the tuple")
else:
    print("kiwi is not in the tuple.")
# Out:
# kiwi is not in the tuple.

# %%
Q17) write a code to clear all elements from the set {1,2,3,4,5}.

# %%
my_set = {1,2,3,4,5}
my_set.clear()
print(my_set)
# Out:
# set()

# %%
Q18) write a code to remove the element 4 from the set {1,2,3,4}.

# %%
my_set = {1,2,3,4}
my_set.remove(4)
print(my_set)
# Out:
# {1, 2, 3}

# %%
Q19) write a code to find the union of two sets {1,2,3} and {3,4,5}.

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1.union(set2)
print(union_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
Q20) write a code to find the intersecion of two sets {1,2,3} and {2,3,4}

# %%
set1 = {1, 2, 3}
set2 = {2, 3, 4}
intersection_set = set1.intersection(set2)
print(intersection_set)
# Out:
# {2, 3}

# %%
Q21) write a code to create a dictionary with the keys "name","age", and "city",and print it.

# %%
person = {
    "name":"om",
    "age":30,
    "city":"new York"
}
print(person)
# Out:
# {'name': 'om', 'age': 30, 'city': 'new York'}

# %%
Q22) write a code to add a new key-value pair "country":"USA" to the dictionary {'name':'john','age':25}

# %%
user_info = {'name':'john','age':25}
user_info['country'] = 'USA'
print(user_info)
# Out:
# {'name': 'john', 'age': 25, 'country': 'USA'}

# %%
Q23) write a code to access the value associated with the key "name" in the dictionary  {'name':'Alice','age':30}

# %%
data = {'name':'Alice','age':30}
value = data["name"]
print(value)
# Out:
# Alice

# %%
Q24) write a code to remove the key"age" from the dictionary {'name':'Bob','age':22,'city':New York'}

# %%
person = {'name':'Bob','age':22,'city':'New York'}
del person['age']
print(person)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
Q25) write a code to check if the key "city" exists in the dictionary  {'name':'Alice','city':'paris'}

# %%
person = {'name':'Alice','city':'paris'}
if "city" in person:
    print("the key 'city' exist")
else:
    print("the key does not in exist.")
# Out:
# the key 'city' exist

# %%
Q26) write a code to create a list,a tuple,and a dictionary,and print them all.

# %%
my_list = [1, 2, 3, 'a', 'b', 'c']
my_tuple = (10, 20, 30, 'x', 'y','z')
my_dict = {'key1':'value1','key2':'value2','key3':'value3'}
print(my_list)
print(my_tuple)
print(my_dict)
# Out:
# [1, 2, 3, 'a', 'b', 'c']
# (10, 20, 30, 'x', 'y', 'z')
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}
