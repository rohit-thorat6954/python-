# %%
Q 1) what is a Restful API?
>> a RESTful API (Representation state transfer Application programming interface)
    is an architectural style for desigining networked application

# %%
Q 2) Explain the concept of API specification.
>> an API specification is a blueprint or contract that defines how a developer can interact with a particular API.

# %%
Q 3) what is Flask,and why is it popular for building APIs?
>> Flask is a lightweight python web framework
  popular for building APIs due to its simplicity,flexiblity and minimal overhead.

# %%
Q 4) what is routing in flask?
>> Routing in flask is the process of mapping URLs to specific functions that handle the user's request.

# %%
Q 5) how do you create a simple Flask application?
>> a simple Flask application is created by importing flask class,creating an instance of the class, defining a route using 
     a decorator and running the application

# %%
Q 6) what are HTTP methods used in RESTful APIs?
>> The primary HTTP methods used in RESTful APIs are GET,POST,PUT,DELETE,and PATCH.

# %%
Q 7) what is the purpose of the @app.route() decorator in Flask?
>> The @app.route() decorator in flask is used to bind a URL  path to a specific function

# %%
Q 8) what is the difference between GET and POST HTTP methods?
>> GET > request retrieve data from a server
   POST > request submit data to be processed by a server

# %%
Q 9) how do you handle errors in Flask APIs?
>> 1. @app.errorhandler()
   2. app.register_error_handler()

# %%
Q 10) How do you connect Flask to a SQL database?
>> using an Object-Relational Mapper (ORM) like flask-SQLAlchemy

# %%
Q 11) what is the role of Flask-SQLAlchemy?
>> Flask-SQLAlchemy is an extension that simplifies the integration of the SQLAlchemy ORM with the flask web framework

# %%
Q 12) what are flask  blueprints and how are they useful?
>> Flask blueprints are a way to organize a flask application into smaller,self-contained modules or components.

# %%
Q 13) what are the purpose of flask's request object?
>> the Flask request objectis a container that encapsulates the details of an incoming HTTP request from a client to the server

# %%
Q 14) how do you create a RESTful API endpoint using flask?
>> using the @app.route()

# %%
Q 15) what are the purpose of flask's jsonify() fuction?
>> flask's jsonify() is used to convert python objects into a JSON formatted response object with the correct

# %%
Q 16) Explain Flask's url_for() function.
>> in flask is used to dynamically build a URL for a specific function

# %%
Q 17) how does flask handle static files(css,javascript,etc)?
>>  flask handle static files by serving them from a designated directory named 'static' within the application root directory

# %%
Q 18) how do you handle POST request in flask?
>> you specify methods=['POST'] in route decorator and access the submitted data using the request object
    typically request.form

# %%
Q 19) how would you secure a flask API?
>> implementing several layers of defense, including using HTTPS,robust authentication and authorization mechanisms,input validation

# %%
Q 20) what is the role of Flask's session object?
>> The session object is used to store data specific to a user from one request to the next.

# %% [markdown]
# # PRACTICAL

# %%
Q 1) how do you create a basic Flask application?
>> 1.create project folder
2.open folder with vs code
3.setup python virtual environment
4.activate virtual environment
5.install flask
6.install dependencies and set environment variables
7.create entry file
8.import flask

# %%
Q 2) how do you serve static files like images or css in flask?
   <link rel="stylesheet" href="[[ url_for('static', filename='css/style') }}">

# %%
Q 3) How do you define different routes with different HTTP methods  in flask?
>>  @app.route('/login', methods=['GET', 'POST'])
    def login():
        if request.method == 'POST':
            return 'POST request received'
        else:
             return 'POST request received'

# %%
Q 4) how do you render HTML templates in flask?
>> the render_template() function is used to render html templtes in flask

# %%
Q 5) how do you handle forms in flask?
>> from flask import request,redirect , url_for

   @app.route('/submit_form',methods=['POST'])
   def submit_form():
       if request.method == 'POST":
       username = request.form['username']
       return redirect(url_for('success', user=username))

# %%
Q 6) how can you validate form data in flask?
>> if not request.form['title']:
    flash('title is required')
   if not request.form['content']:
       flash('content is required')
   else:

# %%
Q 7) how do you manage sessions in flask?
>> app.config['SECRET_KEY'] = 'a-log-random-secret-key'

# %%
Q 8) how do you handle errors in flask(e.g.404)?
>> @app.errorhandler()

# %%
Q 9)how do you structure a flask app using Blueprints?
>> from flask import Blueprint
   admin_bp = Blueprint('admin', __name__, template_folder='templates')

# %%
Q 10) how do you return JSON response in Flask?
>> from flask import jsonify
   @app.route('/data')
   def get_data():
       data = {"message": "hello, world"}
       return jsonify(data)

# %%
Q 11) how do you capture URL parameters in Flask?
>> from flask import request 
   @app.route('/search')
   def search():
       query = request.args.get('query', 'default_query')
       return f"search result for : {query}"
